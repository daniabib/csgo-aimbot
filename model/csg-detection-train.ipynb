# %%
# %%capture
# !git clone https://github.com/ultralytics/yolov5.git
# %cd /content/yolov5
# !pip install -r requirements.txt
# !pip install wandb==0.12.10

# %%
# !python val.py --weights ../csgo-detection-v2.pt --data Csgo_wandb.yaml --img 600 --half
# Out:
# val: data=Csgo_wandb.yaml, weights=['../csgo-detection-v2.pt'], batch_size=32, imgsz=600, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-270-g6935a54 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Fusing layers...
# Model summary: 367 layers, 46135203 parameters, 0 gradients
# WARNING: --img-size 600 must be multiple of max stride 32, updating to 608
#
# Dataset not found ⚠, missing paths ['/content/yolov5/wandb-artifact:/csgo-detection/val']
# Traceback (most recent call last):
#   File "val.py", line 394, in <module>
#     main(opt)
#   File "val.py", line 367, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "val.py", line 153, in run
#     data = check_dataset(data)  # check
#   File "/content/yolov5/utils/general.py", line 487, in check_dataset
#     raise Exception(emojis('Dataset not found ❌'))
# Exception: Dataset not found ❌

# %%
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5x.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-270-g6935a54 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5x.pt to yolov5x.pt...
# 100% 166M/166M [00:04<00:00, 37.1MB/s]
#
# Fusing layers...
# YOLOv5x summary: 444 layers, 86705005 parameters, 0 gradients
#
# Dataset not found ⚠, missing paths ['/content/datasets/coco/val2017.txt']
# Downloading https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip to ../datasets/coco2017labels.zip...
# 100% 67.7M/67.7M [00:00<00:00, 246MB/s]
# Unzipping ../datasets/coco2017labels.zip...
# Downloading http://images.cocodataset.org/zips/train2017.zip to ../datasets/coco/images/train2017.zip...
# Downloading http://images.cocodataset.org/zips/val2017.zip to ../datasets/coco/images/val2017.zip...
# Downloading http://images.cocodataset.org/zips/test2017.zip to ../datasets/coco/images/test2017.zip...
# Unzipping ../datasets/coco/images/val2017.zip...
# Traceback (most recent call last):
#   File "val.py", line 394, in <module>
#     main(opt)
#   File "val.py", line 367, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py", line 27, in decorate_context
#     return func(*args, **kwargs)
#   File "val.py", line 153, in run
#     data = check_dataset(data)  # check
#   File "/content/yolov5/utils/general.py", line 502, in check_dataset
#   File "<string>", line 15, in <module>
#   File "/content/yolov5/utils/general.py", line 584, in download
#     pool.join()
#   File "/usr/lib/python3.7/multiprocessing/pool.py", line 556, in join
#     self._worker_handler.join()
#   File "/usr/lib/python3.7/threading.py", line 1044, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.7/threading.py", line 1060, in _wait_for_tstate_lock
#     elif lock.acquire(block, timeout):
# KeyboardInterrupt

# %%
# !python train.py \
  --data ../Csgo_wandb.yaml \
  --epochs 300 \
  --project csgo-detection \
  --bbox_interval 1 \
  --save-period 1 \
  --weights yolov5l.pt
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 2
# wandb: You chose 'Use an existing W&B account'
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# train: weights=yolov5l.pt, cfg=, data=../Csgo_wandb.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=csgo-detection, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-244-g47233e1 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# TensorBoard: Start with 'tensorboard --logdir csgo-detection', view at http://localhost:6006/
# wandb: Currently logged in as: daniabib (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.17 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run misunderstood-monkey-6
# wandb: ⭐️ View project at https://wandb.ai/daniabib/csgo-detection
# wandb: 🚀 View run at https://wandb.ai/daniabib/csgo-detection/runs/3p87czkp
# wandb: Run data is saved locally in /content/yolov5/wandb/run-20220603_221509-3p87czkp
# wandb: Run `wandb offline` to turn off syncing.
#
# wandb: Downloading large artifact train:latest, 2061.62MB. 4158 files... Done. 0:0:0
# wandb: Downloading large artifact val:latest, 525.08MB. 1042 files... Done. 0:0:0
# wandb: Downloading large artifact val:latest, 525.08MB. 1042 files... Done. 0:0:0
# Mapping dataset
# 100% 260/260 [00:00<00:00, 1578175.17it/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.1/yolov5l.pt to yolov5l.pt...
# 100% 89.3M/89.3M [00:03<00:00, 24.2MB/s]
#
# Overriding model.yaml nc=80 with nc=6
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     59235  models.yolo.Detect                      [6, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# Model summary: 468 layers, 46165219 parameters, 46165219 gradients, 108.0 GFLOPs
#
# Transferred 607/613 items from yolov5l.pt
# AMP: checks passed ✅
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 101 weight (no decay), 104 weight, 104 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning 'artifacts/train:v0/data/labels' images and labels...1039 found, 0 missing, 53 empty, 0 corrupt: 100% 1039/1039 [00:06<00:00, 168.44it/s]
# train: New cache created: artifacts/train:v0/data/labels.cache
# val: Scanning 'artifacts/val:v0/data/labels' images and labels...260 found, 0 missing, 11 empty, 0 corrupt: 100% 260/260 [00:01<00:00, 145.60it/s]
# val: New cache created: artifacts/val:v0/data/labels.cache
# Plotting labels to csgo-detection/exp/labels.jpg...
#
# AutoAnchor: 4.61 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to csgo-detection/exp
# Starting training for 300 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/299     9.76G    0.1152   0.04529   0.05567       107       640:   2% 1/65 [00:04<04:34,  4.28s/it]Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
#      0/299     9.81G   0.09146   0.04326   0.04769        65       640: 100% 65/65 [01:33<00:00,  1.44s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.602      0.105     0.0863     0.0299
# Saving model artifact on epoch 1
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/299     9.81G   0.07346   0.02613   0.03609        86       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.54s/it]
#                  all        260        888      0.517      0.239      0.175     0.0623
# Saving model artifact on epoch 2
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/299     9.81G   0.06797   0.02251   0.03084        94       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.375      0.475      0.394      0.136
# Saving model artifact on epoch 3
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/299     9.81G   0.06036   0.02104   0.02271        73       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.432      0.544      0.496      0.226
# Saving model artifact on epoch 4
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/299     9.81G    0.0499    0.0208   0.01465       104       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.50s/it]
#                  all        260        888      0.546      0.633      0.646      0.296
# Saving model artifact on epoch 5
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/299     9.81G   0.04506   0.01982   0.01253       103       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.613      0.746      0.716       0.36
# Saving model artifact on epoch 6
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/299     9.81G   0.04296   0.02036   0.01123        89       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.651       0.78       0.74      0.376
# Saving model artifact on epoch 7
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      7/299     9.81G   0.04084   0.01927   0.01076        76       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888       0.66      0.752      0.756      0.417
# Saving model artifact on epoch 8
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      8/299     9.81G   0.03793    0.0186   0.00988        86       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        888      0.625      0.798       0.72      0.397
# Saving model artifact on epoch 9
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      9/299     9.81G    0.0389   0.01835  0.009786        87       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.702      0.829      0.757      0.406
# Saving model artifact on epoch 10
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     10/299     9.81G   0.03766   0.01866  0.009413        96       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        886      0.677        0.8      0.759      0.419
# Saving model artifact on epoch 11
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     11/299     9.81G   0.03713   0.01868  0.008513       107       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        887      0.741      0.774      0.757       0.42
# Saving model artifact on epoch 12
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     12/299     9.81G    0.0346   0.01825   0.00847        78       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        888      0.712       0.82      0.808      0.469
# Saving model artifact on epoch 13
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     13/299     9.81G   0.03503   0.01819  0.007906       114       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        888      0.809      0.773      0.821       0.48
# Saving model artifact on epoch 14
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     14/299     9.81G   0.03436   0.01799  0.007327        99       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888      0.823      0.809      0.844       0.49
# Saving model artifact on epoch 15
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     15/299     9.81G   0.03463   0.01755  0.006423        76       640: 100% 65/65 [01:29<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.48s/it]
#                  all        260        885      0.812      0.832      0.848        0.5
# Saving model artifact on epoch 16
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     16/299     9.81G   0.03413   0.01755  0.005758        89       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:14<00:00,  1.60s/it]
#                  all        260        888      0.831      0.854      0.859      0.524
# Saving model artifact on epoch 17
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     17/299     9.81G   0.03319   0.01707   0.00582        99       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888      0.848      0.823      0.847      0.479
# Saving model artifact on epoch 18
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     18/299     9.81G    0.0334   0.01667  0.005761        63       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        888      0.815      0.793      0.839       0.48
# Saving model artifact on epoch 19
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     19/299     9.81G   0.03363   0.01725  0.005816        86       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.48s/it]
#                  all        260        888      0.827      0.818      0.857      0.522
# Saving model artifact on epoch 20
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     20/299     9.81G   0.03121   0.01655  0.006206        90       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        888      0.847      0.814      0.852       0.52
# Saving model artifact on epoch 21
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     21/299     9.81G   0.03168    0.0167  0.005564       118       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888       0.86      0.786       0.81      0.475
# Saving model artifact on epoch 22
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     22/299     9.81G   0.03088   0.01651  0.005401        99       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.46s/it]
#                  all        260        888      0.802      0.816      0.822      0.511
# Saving model artifact on epoch 23
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     23/299     9.81G   0.03227   0.01699  0.005713       118       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.55s/it]
#                  all        260        888      0.887      0.781      0.823      0.506
# Saving model artifact on epoch 24
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     24/299     9.81G   0.03149   0.01663   0.00506        76       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        886       0.87      0.801      0.857      0.506
# Saving model artifact on epoch 25
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     25/299     9.81G   0.03075   0.01554  0.005235        84       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888      0.852      0.796      0.845      0.508
# Saving model artifact on epoch 26
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     26/299     9.81G   0.02969   0.01628  0.004704        68       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.857      0.847      0.858      0.523
# Saving model artifact on epoch 27
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     27/299     9.81G   0.02976   0.01599  0.004366       100       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.38s/it]
#                  all        260        888      0.864      0.834      0.849       0.51
# Saving model artifact on epoch 28
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     28/299     9.81G   0.02975   0.01589  0.004165       117       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.891      0.829      0.885      0.547
# Saving model artifact on epoch 29
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     29/299     9.81G   0.02881   0.01626  0.004358       123       640: 100% 65/65 [01:29<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888      0.848       0.82       0.86      0.512
# Saving model artifact on epoch 30
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     30/299     9.81G   0.02942   0.01596  0.004313       108       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888      0.887      0.791      0.867       0.52
# Saving model artifact on epoch 31
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     31/299     9.81G   0.02913   0.01557  0.004592        97       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.857      0.829      0.863      0.543
# Saving model artifact on epoch 32
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     32/299     9.81G   0.02804    0.0156  0.003774        72       640: 100% 65/65 [01:29<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888      0.873      0.785      0.848       0.53
# Saving model artifact on epoch 33
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     33/299     9.81G   0.02873   0.01543  0.004198        75       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.51s/it]
#                  all        260        887      0.898      0.821      0.864      0.547
# Saving model artifact on epoch 34
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     34/299     9.81G   0.02905   0.01508  0.003777        91       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        887      0.892      0.819      0.864      0.542
# Saving model artifact on epoch 35
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     35/299     9.81G   0.02817   0.01482  0.003613       113       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        888      0.902      0.802      0.862      0.533
# Saving model artifact on epoch 36
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     36/299     9.81G   0.02687   0.01502  0.003505       120       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.49s/it]
#                  all        260        888      0.902      0.808      0.874      0.541
# Saving model artifact on epoch 37
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     37/299     9.81G   0.02818   0.01468  0.003738       105       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:14<00:00,  1.58s/it]
#                  all        260        888      0.875      0.827       0.87      0.528
# Saving model artifact on epoch 38
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     38/299     9.81G    0.0289   0.01527  0.003878       124       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        887      0.885       0.83      0.877      0.534
# Saving model artifact on epoch 39
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     39/299     9.81G   0.02782   0.01471  0.003889        85       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.867      0.823      0.873      0.556
# Saving model artifact on epoch 40
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     40/299     9.81G   0.02745   0.01505  0.003513        88       640: 100% 65/65 [01:29<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.856       0.84      0.861      0.538
# Saving model artifact on epoch 41
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     41/299     9.81G    0.0266   0.01469  0.003673       124       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888      0.853      0.853      0.874       0.56
# Saving model artifact on epoch 42
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     42/299     9.81G    0.0263   0.01448  0.003737        87       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.50s/it]
#                  all        260        888      0.889      0.829      0.888       0.55
# Saving model artifact on epoch 43
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     43/299     9.81G   0.02738   0.01439  0.003274        97       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.49s/it]
#                  all        260        888       0.91      0.841      0.898      0.563
# Saving model artifact on epoch 44
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     44/299     9.81G     0.026   0.01445  0.003424        72       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.48s/it]
#                  all        260        887      0.831      0.844      0.862      0.544
# Saving model artifact on epoch 45
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     45/299     9.81G    0.0265   0.01501  0.003493        72       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        887      0.913      0.848      0.877      0.555
# Saving model artifact on epoch 46
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     46/299     9.81G   0.02651   0.01403  0.003316        99       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.46s/it]
#                  all        260        888      0.906      0.844      0.898      0.587
# Saving model artifact on epoch 47
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     47/299     9.81G   0.02593   0.01363  0.002885       113       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888      0.888      0.856      0.889      0.573
# Saving model artifact on epoch 48
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     48/299     9.81G   0.02593   0.01421  0.003324        75       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        887      0.883      0.836      0.867       0.54
# Saving model artifact on epoch 49
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     49/299     9.81G   0.02495   0.01411  0.003371        85       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.48s/it]
#                  all        260        887       0.91       0.83       0.88      0.557
# Saving model artifact on epoch 50
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     50/299     9.81G   0.02637   0.01439  0.003469       138       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.49s/it]
#                  all        260        888      0.876      0.831      0.867      0.548
# Saving model artifact on epoch 51
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     51/299     9.81G   0.02607   0.01377  0.003663       106       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        888      0.894       0.81      0.869      0.552
# Saving model artifact on epoch 52
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     52/299     9.81G   0.02498   0.01401  0.003175        97       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888      0.851      0.826      0.858      0.556
# Saving model artifact on epoch 53
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     53/299     9.81G   0.02399   0.01367   0.00341       103       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        888      0.864      0.836      0.867      0.553
# Saving model artifact on epoch 54
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     54/299     9.81G   0.02548   0.01364  0.003453        96       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.51s/it]
#                  all        260        888      0.859      0.873      0.883      0.565
# Saving model artifact on epoch 55
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     55/299     9.81G   0.02464   0.01379  0.003394        96       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.884      0.834      0.866      0.559
# Saving model artifact on epoch 56
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     56/299     9.81G   0.02455   0.01429  0.003411       127       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888      0.863      0.819       0.84       0.54
# Saving model artifact on epoch 57
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     57/299     9.81G   0.02462   0.01324  0.003385        71       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.47s/it]
#                  all        260        888      0.884      0.821      0.864      0.547
# Saving model artifact on epoch 58
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     58/299     9.81G   0.02538   0.01346  0.002825       121       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        887      0.851       0.86      0.859      0.552
# Saving model artifact on epoch 59
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     59/299     9.81G   0.02387   0.01346  0.002874        71       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        886      0.897      0.837      0.869      0.558
# Saving model artifact on epoch 60
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     60/299     9.81G   0.02468   0.01372  0.002897        51       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.887      0.845      0.867      0.549
# Saving model artifact on epoch 61
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     61/299     9.81G   0.02323   0.01331  0.002841       101       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.892      0.841      0.873      0.563
# Saving model artifact on epoch 62
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     62/299     9.81G   0.02422   0.01341  0.002874        81       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888       0.94      0.798      0.891      0.572
# Saving model artifact on epoch 63
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     63/299     9.81G   0.02444   0.01342  0.002931        84       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        886      0.889      0.838      0.859      0.539
# Saving model artifact on epoch 64
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     64/299     9.81G   0.02391   0.01324  0.003083        85       640: 100% 65/65 [01:28<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.891      0.841      0.874      0.565
# Saving model artifact on epoch 65
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     65/299     9.81G   0.02335   0.01318  0.002832        90       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888       0.89      0.824      0.875      0.565
# Saving model artifact on epoch 66
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     66/299     9.81G   0.02389   0.01337  0.002871        67       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        885      0.899      0.824      0.865      0.561
# Saving model artifact on epoch 67
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     67/299     9.81G   0.02355    0.0136  0.003203       114       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.46s/it]
#                  all        260        885      0.908      0.847      0.888      0.579
# Saving model artifact on epoch 68
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     68/299     9.81G   0.02345   0.01287  0.002945        76       640: 100% 65/65 [01:28<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        885      0.916       0.83      0.886      0.571
# Saving model artifact on epoch 69
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     69/299     9.81G   0.02392   0.01349  0.003124        89       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.46s/it]
#                  all        260        885      0.854      0.864      0.881      0.568
# Saving model artifact on epoch 70
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     70/299     9.81G    0.0238   0.01282  0.003094        69       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        885      0.887       0.84      0.871      0.564
# Saving model artifact on epoch 71
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     71/299     9.81G   0.02275   0.01286   0.00298        96       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        887      0.905      0.851      0.887      0.576
# Saving model artifact on epoch 72
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     72/299     9.81G    0.0236   0.01328  0.003015        88       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        888      0.911      0.851      0.887      0.574
# Saving model artifact on epoch 73
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     73/299     9.81G   0.02281   0.01332  0.002768        86       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.884      0.833      0.873      0.569
# Saving model artifact on epoch 74
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     74/299     9.81G   0.02316   0.01298   0.00265       111       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.36s/it]
#                  all        260        887      0.857      0.836      0.864      0.557
# Saving model artifact on epoch 75
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     75/299     9.81G   0.02203   0.01285  0.002706        97       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.49s/it]
#                  all        260        888       0.88      0.801      0.856      0.554
# Saving model artifact on epoch 76
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     76/299     9.81G   0.02212   0.01243  0.002603        94       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.908      0.819      0.874      0.573
# Saving model artifact on epoch 77
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     77/299     9.81G   0.02219   0.01249  0.002591        82       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        887       0.89      0.823      0.877      0.574
# Saving model artifact on epoch 78
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     78/299     9.81G   0.02222   0.01281  0.002823       122       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        887      0.902      0.832      0.883      0.578
# Saving model artifact on epoch 79
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     79/299     9.81G   0.02247    0.0124  0.002628        79       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        887      0.861      0.873       0.88      0.573
# Saving model artifact on epoch 80
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     80/299     9.81G   0.02146   0.01266  0.002546       114       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        885        0.9      0.844      0.885      0.583
# Saving model artifact on epoch 81
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     81/299     9.81G   0.02168   0.01235   0.00266       104       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.862      0.845      0.864      0.573
# Saving model artifact on epoch 82
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     82/299     9.81G    0.0223   0.01276   0.00279        82       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        887      0.881      0.841      0.884      0.571
# Saving model artifact on epoch 83
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     83/299     9.81G   0.02162   0.01236  0.002674        95       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        888      0.883       0.82      0.865      0.559
# Saving model artifact on epoch 84
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     84/299     9.81G   0.02133   0.01269  0.002816        85       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.52s/it]
#                  all        260        887      0.877      0.841      0.881      0.573
# Saving model artifact on epoch 85
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     85/299     9.81G   0.02194   0.01246  0.002586        71       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        887      0.894      0.842      0.884      0.575
# Saving model artifact on epoch 86
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     86/299     9.81G   0.02193   0.01255  0.002553        92       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        888      0.899      0.861      0.889       0.57
# Saving model artifact on epoch 87
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     87/299     9.81G   0.02182   0.01227  0.002362       109       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        887      0.918      0.834      0.892       0.57
# Saving model artifact on epoch 88
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     88/299     9.81G   0.02148   0.01217  0.002606        73       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        887      0.922      0.839       0.89      0.562
# Saving model artifact on epoch 89
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     89/299     9.81G    0.0218    0.0119  0.002412        88       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        887      0.898      0.864      0.896      0.574
# Saving model artifact on epoch 90
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     90/299     9.81G    0.0214   0.01205  0.002525       122       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887       0.92      0.836      0.903      0.586
# Saving model artifact on epoch 91
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     91/299     9.81G   0.02053   0.01179    0.0025        92       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.902      0.834      0.888      0.584
# Saving model artifact on epoch 92
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     92/299     9.81G   0.02095   0.01211  0.002578        87       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        888      0.933      0.824      0.901      0.593
# Saving model artifact on epoch 93
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     93/299     9.81G   0.02095   0.01208  0.002554        91       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.37s/it]
#                  all        260        887      0.942      0.841      0.905      0.585
# Saving model artifact on epoch 94
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     94/299     9.81G   0.02158   0.01235  0.002542        81       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.38s/it]
#                  all        260        887      0.895      0.855      0.891      0.574
# Saving model artifact on epoch 95
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     95/299     9.81G   0.02061   0.01193    0.0023        99       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        888      0.906      0.885       0.92      0.604
# Saving model artifact on epoch 96
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#     96/299     9.81G   0.02038   0.01216  0.002359        88       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        887      0.929      0.873      0.919      0.594
# Saving model artifact on epoch 97
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
# ...
#                  all        260        887      0.908      0.828      0.882      0.587
# Saving model artifact on epoch 108
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    108/299     9.81G   0.01996   0.01175  0.002287        91       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.925      0.835      0.894      0.586
# Saving model artifact on epoch 109
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    109/299     9.81G   0.01953   0.01101  0.002261       100       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.921      0.827      0.868      0.563
# Saving model artifact on epoch 110
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    110/299     9.81G   0.01956   0.01126  0.002176        87       640: 100% 65/65 [01:28<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        888      0.888      0.838      0.877      0.575
# Saving model artifact on epoch 111
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    111/299     9.81G   0.02014   0.01164  0.002333        74       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.37s/it]
#                  all        260        887      0.894      0.845      0.882      0.581
# Saving model artifact on epoch 112
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    112/299     9.81G   0.01901   0.01106  0.002302       104       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.52s/it]
#                  all        260        887      0.918      0.823      0.878      0.581
# Saving model artifact on epoch 113
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    113/299     9.81G    0.0195   0.01155  0.002304        93       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.38s/it]
#                  all        260        887      0.882      0.849      0.868      0.577
# Saving model artifact on epoch 114
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    114/299     9.81G   0.01976   0.01177  0.002205        59       640: 100% 65/65 [01:28<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        887      0.914      0.826      0.875      0.581
# Saving model artifact on epoch 115
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    115/299     9.81G   0.01994   0.01149  0.002058        87       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        888      0.893       0.85      0.878       0.58
# Saving model artifact on epoch 116
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    116/299     9.81G   0.01921   0.01113  0.002318        87       640: 100% 65/65 [01:29<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        885      0.934       0.82      0.879      0.578
# Saving model artifact on epoch 117
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    117/299     9.81G   0.01892   0.01108  0.002187        68       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        887      0.897      0.826      0.859      0.565
# Saving model artifact on epoch 118
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    118/299     9.81G   0.01916   0.01136  0.002176       102       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.48s/it]
#                  all        260        887      0.913      0.816      0.867      0.567
# Saving model artifact on epoch 119
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    119/299     9.81G   0.01961   0.01129   0.00219        73       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.889      0.834      0.866      0.567
# Saving model artifact on epoch 120
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    120/299     9.81G   0.01853   0.01128  0.002268        95       640: 100% 65/65 [01:29<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        887      0.878       0.84      0.862      0.565
# Saving model artifact on epoch 121
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    121/299     9.81G   0.01848   0.01113  0.002193        98       640: 100% 65/65 [01:29<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        887      0.897      0.838      0.872      0.574
# Saving model artifact on epoch 122
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    122/299     9.81G   0.01868    0.0108  0.002201        83       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.913      0.824      0.876      0.571
# Saving model artifact on epoch 123
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    123/299     9.81G   0.01919   0.01067  0.002248        68       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.43s/it]
#                  all        260        887      0.878      0.834      0.872       0.57
# Saving model artifact on epoch 124
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    124/299     9.81G   0.01849   0.01095  0.002096        67       640: 100% 65/65 [01:28<00:00,  1.37s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.42s/it]
#                  all        260        887      0.903      0.847      0.878      0.579
# Saving model artifact on epoch 125
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    125/299     9.81G   0.01862   0.01056  0.002294        96       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.915      0.832      0.881      0.578
# Saving model artifact on epoch 126
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    126/299     9.81G   0.01877   0.01119  0.002389        67       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.39s/it]
#                  all        260        887      0.918      0.834      0.886      0.585
# Saving model artifact on epoch 127
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    127/299     9.81G    0.0179   0.01078  0.002109        79       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.873      0.838       0.89      0.586
# Saving model artifact on epoch 128
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    128/299     9.81G   0.01847   0.01111  0.002205       101       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        885      0.923      0.838       0.88      0.571
# Saving model artifact on epoch 129
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    129/299     9.81G   0.01846   0.01086   0.00206        80       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        887      0.901      0.828      0.885       0.58
# Saving model artifact on epoch 130
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    130/299     9.81G   0.01882   0.01062  0.002162        96       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.38s/it]
#                  all        260        885      0.909       0.84      0.874      0.572
# Saving model artifact on epoch 131
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    131/299     9.81G   0.01801   0.01057  0.002216       101       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.55s/it]
#                  all        260        885      0.882      0.866      0.872      0.573
# Saving model artifact on epoch 132
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    132/299     9.81G   0.01845   0.01043  0.002134       101       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.906       0.86      0.873      0.574
# Saving model artifact on epoch 133
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    133/299     9.81G   0.01781   0.01072   0.00209        97       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.894      0.852      0.883      0.576
# Saving model artifact on epoch 134
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    134/299     9.81G   0.01793    0.0106  0.002063        75       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.48s/it]
#                  all        260        887      0.878      0.853      0.874       0.57
# Saving model artifact on epoch 135
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    135/299     9.81G   0.01716   0.01036  0.001975        97       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        887      0.893      0.836      0.873      0.574
# Saving model artifact on epoch 136
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    136/299     9.81G   0.01752   0.01054  0.002068       101       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.44s/it]
#                  all        260        887      0.911      0.835      0.871      0.577
# Saving model artifact on epoch 137
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    137/299     9.81G   0.01741   0.01039  0.002134       115       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.50s/it]
#                  all        260        888      0.887       0.83      0.865      0.565
# Saving model artifact on epoch 138
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    138/299     9.81G    0.0174   0.01045  0.002333        67       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.41s/it]
#                  all        260        887      0.908      0.827      0.883      0.574
# Saving model artifact on epoch 139
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    139/299     9.81G   0.01758   0.01063  0.002233        92       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.45s/it]
#                  all        260        887      0.904      0.828      0.862       0.57
# Saving model artifact on epoch 140
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    140/299     9.81G   0.01749   0.01021  0.002098       113       640: 100% 65/65 [01:27<00:00,  1.35s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.51s/it]
#                  all        260        888      0.923       0.83      0.877      0.573
# Saving model artifact on epoch 141
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    141/299     9.81G   0.01795   0.01085   0.00221        91       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:13<00:00,  1.52s/it]
#                  all        260        886      0.932       0.84      0.884      0.577
# Saving model artifact on epoch 142
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    142/299     9.81G   0.01804   0.01054  0.002095        82       640: 100% 65/65 [01:29<00:00,  1.38s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:14<00:00,  1.58s/it]
#                  all        260        888      0.924      0.835      0.865      0.568
# Saving model artifact on epoch 143
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    143/299     9.81G   0.01653  0.009995  0.001802        81       640: 100% 65/65 [01:31<00:00,  1.40s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        887       0.93      0.829      0.872      0.577
# Saving model artifact on epoch 144
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    144/299     9.81G   0.01684    0.0104  0.001954        78       640: 100% 65/65 [01:28<00:00,  1.36s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 9/9 [00:12<00:00,  1.40s/it]
#                  all        260        888      0.909       0.85       0.88       0.58
# Saving model artifact on epoch 145
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    145/299     9.81G   0.01661   0.01011  0.001857        96       640:  95% 62/65 [01:24<00:04,  1.38s/it]
